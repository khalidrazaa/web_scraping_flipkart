# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
link="https://www.flipkart.com/hp-15s-ryzen-3-dual-core-3250u-4-gb-1-tb-hdd-windows-10-home-15s-gr0006au-thin-light-laptop/product-reviews/itmdbb2d234797b6?pid=COMFZHZFZFFBJBHH&lid=LSTCOMFZHZFZFFBJBHH7WNMPE&marketplace=FLIPKART"

# %%
page=requests.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57
# ...

# %%
soup=bs(page.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.104e9a.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %% [markdown]
# # Title Of the Product

# %%
title=soup.title

# %%
print(soup.title)
# Out:
# <title>Hp 15s Ryzen 3 Dual Core 3250u 4 Gb 1 Tb Hdd Windows 10 Home 15s Gr0006au Thin Light Laptop Reviews: Latest Review of Hp 15s Ryzen 3 Dual Core 3250u 4 Gb 1 Tb Hdd Windows 10 Home 15s Gr0006au Thin Light Laptop | Price in India | Flipkart.com</title>

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(title.string)
# Out:
# Hp 15s Ryzen 3 Dual Core 3250u 4 Gb 1 Tb Hdd Windows 10 Home 15s Gr0006au Thin Light Laptop Reviews: Latest Review of Hp 15s Ryzen 3 Dual Core 3250u 4 Gb 1 Tb Hdd Windows 10 Home 15s Gr0006au Thin Light Laptop | Price in India | Flipkart.com

# %% [markdown]
# # Check Product Price

# %%
price=soup.find_all("div",class_="_30jeq3")

# %%
price
# Out:
# [<div class="_30jeq3">₹32,990</div>]

# %%
product_price=[]

for i in range(0,len(price)):
    product_price.append(price[i].get_text())

# %%
product_price
# Out:
# ['₹32,990']

# %%
price[i].get_text()
# Out:
# '₹32,990'

# %% [markdown]
# # Scrap Customer Names

# %%
names=soup.find_all("p",class_="_2sc7ZR _2V5EHH")
names
# Out:
# [<p class="_2sc7ZR _2V5EHH">Vaibhav Bharati</p>,
#  <p class="_2sc7ZR _2V5EHH">MD MATHIN ALI</p>,
#  <p class="_2sc7ZR _2V5EHH">Sayani  Banerjee </p>,
#  <p class="_2sc7ZR _2V5EHH">Satyajit Swain</p>,
#  <p class="_2sc7ZR _2V5EHH">Vijay Singh  Shekhawat</p>,
#  <p class="_2sc7ZR _2V5EHH">Anoop Mathew</p>,
#  <p class="_2sc7ZR _2V5EHH">Vivek Raturi</p>,
#  <p class="_2sc7ZR _2V5EHH">Anand Amirtharaj</p>,
#  <p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>,
#  <p class="_2sc7ZR _2V5EHH">Shivani  Pankaj</p>]

# %%
cust_name=[]

for i in  range(0,len(names)):
    cust_name.append(names[i].get_text())

# %%
cust_name
# Out:
# ['Vaibhav Bharati',
#  'MD MATHIN ALI',
#  'Sayani  Banerjee ',
#  'Satyajit Swain',
#  'Vijay Singh  Shekhawat',
#  'Anoop Mathew',
#  'Vivek Raturi',
#  'Anand Amirtharaj',
#  'Flipkart Customer',
#  'Shivani  Pankaj']

# %% [markdown]
# # Scrap Reviews

# %%
review=soup.find_all("p",class_="_2-N8zT")
review
# Out:
# [<p class="_2-N8zT">Very Good</p>,
#  <p class="_2-N8zT">Terrific</p>,
#  <p class="_2-N8zT">Worth every penny</p>,
#  <p class="_2-N8zT">Fair</p>,
#  <p class="_2-N8zT">Fair</p>,
#  <p class="_2-N8zT">Just wow!</p>,
#  <p class="_2-N8zT">Good</p>,
#  <p class="_2-N8zT">Wonderful</p>,
#  <p class="_2-N8zT">Very Good</p>,
#  <p class="_2-N8zT">Nice product</p>]

# %%
cust_rev=[]

for i in range(0,len(review)):
    cust_rev.append(review[i].get_text())

# %%
cust_rev
# Out:
# ['Very Good',
#  'Terrific',
#  'Worth every penny',
#  'Fair',
#  'Fair',
#  'Just wow!',
#  'Good',
#  'Wonderful',
#  'Very Good',
#  'Nice product']

# %%
#soup.find("p",class_="_2-N8zT").get_text()

# %% [markdown]
# # Scrap Comments

# %%
comment=soup.find_all("div",class_="t-ZTKy")
comment
# Out:
# [<div class="t-ZTKy"><div><div class="">Read carefully.. My Experience was complicated just because of boot time i.e. on/off time was too long until I didn't go for updates but once I have done all updates... I am telling you guys...Maska..hai.. Maska..<br/><br/>Superb performance.. and look wise i liked it very much. I use to play GT racing without any lag..<br/><br/>My daughter is also happy for her online studies.<br/><br/>My suggestion is that don't think twice just go for it with Flipkart.<br/><br/>Thanks flipkart for very safe and on time delivery.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
# ...

# %%
cust_comment=[]

for i in range(0,len(comment)):
    cust_comment.append(comment[i].get_text())

# %%
cust_comment
# Out:
# ["Read carefully.. My Experience was complicated just because of boot time i.e. on/off time was too long until I didn't go for updates but once I have done all updates... I am telling you guys...Maska..hai.. Maska..Superb performance.. and look wise i liked it very much. I use to play GT racing without any lag..My daughter is also happy for her online studies.My suggestion is that don't think twice just go for it with Flipkart.Thanks flipkart for very safe and on time delivery.READ MORE",
#  "#Price up to markIts wonderful product for those ,who looking for  student and domestic work1)Its just my dream lappi,(laptop)2)just go for laptop,its really awesome3)I just bought it for my project and bussiness work it's awesome4)one of the best product from HP5)just price is little high ,it have to be reduced6) I loved it7) I recommend it for u,💯💯❤️READ MORE",
# ...

# %% [markdown]
# # Scrap Rating

# %%
rating=soup.find_all("div",class_="_3LWZlK _1BLPMq")
rating
# Out:
# [<div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">4<img class="_1wB99o" src="..."/></div>]

# %%
cust_rating=[]

for i in range(0,len(rating)):
    cust_rating.append(rating[i].get_text())

# %%
cust_rating
# Out:
# ['4', '5', '5', '3', '3', '5', '3', '4', '4', '4']

# %%
import pandas as pd

# %%
df=pd.DataFrame()

df["Customer Names"]=cust_name
df["Customer Review"]=cust_rev
df["Customer Comment"]=cust_comment
df["Ratings"]=cust_rating

# %%
df
# Out:
#            Customer Names    Customer Review  \
# 0         Vaibhav Bharati          Very Good
# 1           MD MATHIN ALI           Terrific
# 2       Sayani  Banerjee   Worth every penny
# 3          Satyajit Swain               Fair
# 4  Vijay Singh  Shekhawat               Fair
# 5            Anoop Mathew          Just wow!
# 6            Vivek Raturi               Good
# 7        Anand Amirtharaj          Wonderful
# 8       Flipkart Customer          Very Good
# 9         Shivani  Pankaj       Nice product
#
#                                     Customer Comment Ratings
# 0  Read carefully.. My Experience was complicated...       4
# 1  #Price up to markIts wonderful product for tho...       5
# 2  Nice laptop and Ryzen 3 is a good processor fo...       5
# 3  This laptop needs to be upgraded to at least 8...       3
# 4  HP Product is Good/Ok, but personally i will p...       3
# 5  Awesome and nice for students and all. The fav...       5
# ...

# %%
df.T
# Out:
#                                                                   0  \
# Customer Names                                      Vaibhav Bharati
# Customer Review                                           Very Good
# Customer Comment  Read carefully.. My Experience was complicated...
# Ratings                                                           4
#
#                                                                   1  \
# Customer Names                                        MD MATHIN ALI
# Customer Review                                            Terrific
# Customer Comment  #Price up to markIts wonderful product for tho...
# Ratings                                                           5
#
#                                                                   2  \
# Customer Names                                    Sayani  Banerjee
# Customer Review                                   Worth every penny
# Customer Comment  Nice laptop and Ryzen 3 is a good processor fo...
# ...

# %%
df.shape
# Out:
# (10, 4)

# %%
df.size
# Out:
# 40

# %%
df.columns
# Out:
# Index(['Customer Names', 'Customer Review', 'Customer Comment', 'Ratings'], dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.to_csv("Hp Product FlipKart Review",index=False)

# %%
df=pd.read_csv("Hp Product FlipKart Review")
df
# Out:
#            Customer Names    Customer Review  \
# 0         Vaibhav Bharati          Very Good
# 1           MD MATHIN ALI           Terrific
# 2       Sayani  Banerjee   Worth every penny
# 3          Satyajit Swain               Fair
# 4  Vijay Singh  Shekhawat               Fair
# 5            Anoop Mathew          Just wow!
# 6            Vivek Raturi               Good
# 7        Anand Amirtharaj          Wonderful
# 8       Flipkart Customer          Very Good
# 9         Shivani  Pankaj       Nice product
#
#                                     Customer Comment  Ratings
# 0  Read carefully.. My Experience was complicated...        4
# 1  #Price up to markIts wonderful product for tho...        5
# 2  Nice laptop and Ryzen 3 is a good processor fo...        5
# 3  This laptop needs to be upgraded to at least 8...        3
# 4  HP Product is Good/Ok, but personally i will p...        3
# 5  Awesome and nice for students and all. The fav...        5
# ...

# %%
df["Customer Review"]
# Out:
# 0            Very Good
# 1             Terrific
# 2    Worth every penny
# 3                 Fair
# 4                 Fair
# 5            Just wow!
# 6                 Good
# 7            Wonderful
# 8            Very Good
# 9         Nice product
# Name: Customer Review, dtype: object

# %%
df["Ratings"].min()
# Out:
# 3

# %%
df["Ratings"].unique()
# Out:
# array([4, 5, 3], dtype=int64)

# %%
df["Ratings"].value_counts()
# Out:
# 4    4
# 5    3
# 3    3
# Name: Ratings, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x=df["Ratings"])
plt.title("Stars")
# Out:
# Text(0.5, 1.0, 'Stars')

# %%
data=['4', '5', '5', '3', '3', '5', '3', '4', '4', '4']
plt.pie(x=data,labels=data,explode=(0,0.3,0.2,0,0,0.2,0,0,0,0),autopct="%1.1f")
plt.show()

# %%
#label=["Names","Rating"]
plt.plot(df["Ratings"],df["Customer Names"],marker="o")

plt.xlabel("Stars")
plt.ylabel("Customer Names")
plt.legend()
plt.title("Rating Chart")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
